# %% [markdown]
# <a href="https://colab.research.google.com/github/acb100cias/EstadisticaDescriptiva/blob/main/EDA_Agua_CDMX.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
agua=pd.read_csv('/content/reportes_agua_2024_01.csv')

# %%
agua.head()

# %%
agua.tail()

# %%
agua.columns.values

# %%
agua.dtypes

# %%
agua.clasificacion.value_counts()

# %%
agua.reporte.value_counts()

# %%
agua.medio_recepcion.value_counts()

# %%
agua1=agua.filter(['fecha_reporte','clasificacion', 'reporte' ,'alcaldia_catalogo'])

# %%
agua=agua.drop_duplicates()

# %%
agua.duplicated().value_counts()

# %%
agua=agua.dropna()

# %%
agua.isnull().sum()

# %%
agua

# %%
agua1=agua.filter(['fecha_reporte','clasificacion', 'reporte' ,'alcaldia_catalogo'])

# %%
agua1=agua1.rename(columns={'fecha_reporte':'fecha','clasificacion':'tipo','alcaldia_catalogo':'alcaldia'})

# %%
agua1

# %%
sb.catplot(x='alcaldia',data=agua1,kind='count')
plt.xticks(rotation=90)

# %%
sb.catplot(x='reporte',data=agua1,kind='count')
plt.xticks(rotation=90)

# %%
sb.catplot(data=agua1,x='reporte',y='alcaldia',kind='swarm')

# %%
sb.catplot(data=agua1,x='reporte',kind='count',col='alcaldia')
plt.xticks(rotation=90)

# %%
G=agua1.groupby('alcaldia')

# %%
Dagua=pd.DataFrame(G)

# %%
for i in Dagua[1]:
  sb.catplot(data=i,x='reporte',kind='count',hue='tipo')
  plt.xticks(rotation=90)
  plt.title(i.alcaldia.unique()[0])
  plt.show()

# %%
agua1

# %%
G2=pd.DataFrame(agua1.groupby('fecha'))

# %%
G2[1][0]

# %%
sb.catplot(data=G2[1][0],x='reporte',kind='count',hue='alcaldia')
plt.xticks(rotation=90)
plt.show()

# %%
for i in G2[1]:
  print(i.value_counts())

# %%
R=[]
for i in G2[1]:
  R.append(i.count().sum()/4)

# %%
r=np.array(R)

# %%
D=G2[0]['Total']=r

# %%
D=G2[0]

# %%
D
d2=pd.DataFrame()

# %%
d2['fecha']=D

# %%
d2['Total']=R

# %%
sb.catplot(data=d2,x='fecha',y='Total',kind='bar')
plt.xticks(rotation=90)
plt.show()

# %%
d2.plot(x='fecha',y='Total',kind='line')
plt.xticks(rotation=90)
plt.show()
