# %% [markdown]
# <a href="https://colab.research.google.com/github/acb100cias/EstadisticaDescriptiva/blob/main/EDA_STC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import seaborn as sb
import pandas as pd
import matplotlib.pyplot as plt

# %%
metro=pd.read_csv('/content/afluenciastc_desglosado_03_2026.csv',encoding='utf8')

# %%
metro.linea[0]

# %%
linea=metro.linea.replace('LÃ­nea 1','Linea 1')

# %%
linea=linea.replace('LÃ­nea 2','Linea 2')

# %%
for i in [1,2,3,4,5,6,7,8,9,12,'A','B']:
  linea=linea.replace('LÃ­nea '+str(i),'Linea '+str(i))

# %%
linea

# %%
metro['linea']=linea

# %%
metro.rename(columns={'anio':'año'},inplace=True)

# %%
D=[]

for i in metro.fecha:
  D.append(i.split('-')[2])

dia={'día':D}

# %%
h='hola,hola,hola'

# %%
h.split(',')

# %%
metro['día']=D

# %%
metro

# %%
metro.afluencia.describe()

# %%
metro

# %%
metro.groupby('mes').afluencia.mean().round(2).plot(kind='bar')

# %%
mensual=metro.groupby('mes').afluencia.mean().round(2)

# %%
mensual.to_csv('mensual.csv',index=False)
mensual.to_excel('mensual.xlsx',index=False)

# %%
sb.catplot(x='mes',y='afluencia',data=metro,kind='bar',col='año').set_axis_labels(rotation=90).savefig('afluenciamensualTotal.jpg')

# %%
PorLinea.to_csv('PorLinea.csv',index=False)
PorLinea.to_excel('PorLinea.xlsx',index=False)

# %%
PorLinea=metro.groupby('linea').afluencia.mean().round(2)

# %%
PorLinea.plot(kind='bar')
plt.savefig('afluenciaporlinea_total.jpg')

# %%
sb.catplot(x='linea',y='afluencia',data=metro,kind='bar',col='año',hue='tipo_pago').set_xticklabels(rotation=90).savefig('afluenciaporlinea.jpg')

# %%
sb.catplot(x='mes',y='afluencia',data=metro,kind='bar',col='año',hue='tipo_pago',).set_xticklabels(rotation=90).savefig('afluenciamensual.jpg')
